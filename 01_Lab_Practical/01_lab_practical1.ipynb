# %%
a =[10,20,30]
b=[1,2,3]
print(a+b)
# Out:
# [10, 20, 30, 1, 2, 3]

# %%
result =[]
for i in range (3):
    result.append(a[i]+b[i])
  
print(result)
# Out:
# [11, 22, 33]

# %%
# !pip install numpy
import numpy as np
a= np.array([10,20,30])
b= np.array([1,2,3])
print(a+b)
# Out:
# ...
# [11 22 33]

# %%
import numpy as np
a= np.array([10,20.5,30])
# b= np.array([1,2,3])
print(a)
print(a.dtype)
# Out:
# [10.  20.5 30. ]
# float64

# %%
# this is the implicit data typecasting in which the datatype is changed to the float 
import numpy as np
a= np.array([10,20.5,30])
b= np.array([1,2,3.0])
print(a+b)
print(a.dtype)
# Out:
# [11.  22.5 33. ]
# float64

# %%
# print("min:",np.sub(a,b) there is no function for the addition and subtraction 
print("mean",np.mean(a))
print("mean",np.mean(b))
print("std dev:",np.std(a))
print("max:",np.max(a))
print("max:",np.max(b))
print("min:",np.min(a))
print("min:",np.min(b))
print(a.dtype)
print(b.dtype)
# Out:
# mean 20.166666666666668
# mean 2.0
# std dev: 8.16836716989523
# max: 30.0
# max: 3.0
# min: 10.0
# min: 1.0
# float64
# float64

# %%
# !pip install pandas
import pandas as pd
# data = [1,2,3,5]

# %%
data = [1,2,3,4]

ser = pd.Series(data)
print(ser)
print(ser.index)
print(ser.values)
print(type(ser))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# RangeIndex(start=0, stop=4, step=1)
# [1 2 3 4]
# <class 'pandas.core.series.Series'>

# %%
data_2d = np.array([1, 2, 3 ,4.5, 5, 6, 7, 8, 9])
ser = pd.Series(data_2d)
print(data_2d)

print(ser[::3])
# Out:
# [1.  2.  3.  4.5 5.  6.  7.  8.  9. ]
# 0    1.0
# 3    4.5
# 6    7.0
# dtype: float64

# %%
days= ["Mon","Tue","Wed","Thru","Fri","Sat","Sun"]
temps = ([30, 40, 50, 12, 35, 25, 10]) 

seq =pd.Series(temps , index =days) 
print(seq)
print(seq.iloc[1])
print(seq['Mon'])
print(seq[::3])
print(seq[:'Tue'])

print(seq.head())
print("first 3",seq.head(3))


print("-------------",seq.head())
print("-------------",seq.tail())
# Out:
# Mon     30
# Tue     40
# Wed     50
# Thru    12
# Fri     35
# Sat     25
# Sun     10
# dtype: int64
# 40
# 30
# Mon     30
# Thru    12
# Sun     10
# dtype: int64
# Mon    30
# Tue    40
# dtype: int64
# Mon     30
# Tue     40
# Wed     50
# Thru    12
# Fri     35
# dtype: int64
# first 3 Mon    30
# Tue    40
# Wed    50
# dtype: int64
# ------------- Mon     30
# Tue     40
# Wed     50
# Thru    12
# Fri     35
# dtype: int64
# ------------- Wed     50
# Thru    12
# Fri     35
# Sat     25
# Sun     10
# dtype: int64

# %% [markdown]
# Now this is going to be the dataframe on the CSV

# %%
# !import numpy

arr = np.array([[1,2],[3,4],[5,6]])

df_np = pd.DataFrame(arr, columns = ['Col1','Col2'])
print(df_np)
# Out:
#    Col1  Col2
# 0     1     2
# 1     3     4
# 2     5     6

# %%
data = {
    'Name':['Amit','Rahul','Priya'],
    'Maths':[78,75,100],
    'Science':[100,45,78]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Maths  Science
# 0   Amit     78      100
# 1  Rahul     75       45
# 2  Priya    100       78

# %%
df['Name'] 
# type(df)
# Out:
# 0     Amit
# 1    Rahul
# 2    Priya
# Name: Name, dtype: object

# %%
df['Maths']
# Out:
# 0     78
# 1     75
# 2    100
# Name: Maths, dtype: int64

# %%
df['Science']
# Out:
# 0    100
# 1     45
# 2     78
# Name: Science, dtype: int64

# %%
df.head()
# Out:
#     Name  Maths  Science
# 0   Amit     78      100
# 1  Rahul     75       45
# 2  Priya    100       78

# %%
df.iloc[1,2]
# Out:
# np.int64(45)

# %%
df.shape
# Out:
# (3, 3)

# %%
# df.columns
df.dtypes
# Out:
# Name       object
# Maths       int64
# Science     int64
# dtype: object

# %%
# df.rename(columns = {'Mathematics' : 'science'}, inplace = True)
df.columns.values[1] = 'Mathematics'

# %%
df
# Out:
#     Name  Mathematics  science  Total  Percentage
# 0   Amit           78      100    178        89.0
# 1  Rahul           75       45    120        60.0
# 2  Priya          100       78    178        89.0

# %%
df['Total'] = df['Mathematics'] + df['science']
df['Percentage'] = ((df['Mathematics'] + df['science'])/200)*100

# %%
df.columns
# Out:
# Index(['Name', 'Mathematics', 'science', 'Total', 'Percentage'], dtype='object')

# %%
df
# Out:
#     Name  Mathematics  science  Total  Percentage
# 0   Amit           78      100    178        89.0
# 1  Rahul           75       45    120        60.0
# 2  Priya          100       78    178        89.0

# %%
df.sort_values(by ='Percentage')
# Out:
#     Name  Mathematics  science  Total  Percentage
# 1  Rahul           75       45    120        60.0
# 0   Amit           78      100    178        89.0
# 2  Priya          100       78    178        89.0

# %%
df.sort_values(by ='Percentage',ascending = False)
# Out:
#     Name  Mathematics  science  Total  Percentage
# 1  Rahul           75       45    120        60.0
# 0   Amit           78      100    178        89.0
# 2  Priya          100       78    178        89.0

# %%
df.drop('total',axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 df.drop('total',axis = 1, inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df
# Out:
#     Name  Mathematics  Total  Percentage
# 1  Rahul           75    120        60.0
# 0   Amit           78    178        89.0
# 2  Priya          100    178        89.0
