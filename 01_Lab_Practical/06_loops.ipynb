# %%
l = [3,5,6,7,67]
for item in l:
    print(item)
for i in range (3):
    print(i)
# Out:
# 3
# 5
# 6
# 7
# 67
# 0
# 1
# 2

# %%
count = 0
while count < 3:
    # if i == 1:
    #     break
    print(count)
    count += 1
# Out:
# 0
# 1
# 2

# %%
l =["apple","banana","tomatos"]
for i in l :
    if(i == "banana"):
        continue
    print(i)
# Out:
# apple
# tomatos
