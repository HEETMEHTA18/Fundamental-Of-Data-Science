# %%
import json

# %%
obj = {"name":"Alice","company":"job","salary":3000}
s = json.dumps(obj)
type(s)
# print(s)
# Out:
# str

# %%
d = json.loads('{"name":"Alice","company":"job","salary":3000}')
type(d)
print(d)
# Out:
# {'name': 'Alice', 'company': 'job', 'salary': 3000}

# %%
file = open("data.json","w")

# %%
json.dump(obj,file)
file.close()
