# %%
text =""" Hello this is the deaseas csv in which the data for the people with some diesease is given in which the 
deasdes table and the bp hight level is given 2.5mgll"""

# %%
text
# Out:
# ' Hello this is the deaseas csv in which the data for the people with some diesease is given in which the \ndeasdes table and the bp hight level is given 2.5mgll'

# %%
import re
text = text.upper()

# %%
text
# Out:
# ' HELLO THIS IS THE DEASEAS CSV IN WHICH THE DATA FOR THE PEOPLE WITH SOME DIESEASE IS GIVEN IN WHICH THE \nDEASDES TABLE AND THE BP HIGHT LEVEL IS GIVEN 2.5MGLL'

# %%
text1 = re.sub(r'[^\w\s]',' ',text)

# %%
text1
# Out:
# ' HELLO THIS IS THE DEASEAS CSV IN WHICH THE DATA FOR THE PEOPLE WITH SOME DIESEASE IS GIVEN IN WHICH THE \nDEASDES TABLE AND THE BP HIGHT LEVEL IS GIVEN 2 5MGLL'

# %%
# !pip install nltk

import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
tokens = word_tokenize(text1)
print(tokens)
# Out:
# ['HELLO', 'THIS', 'IS', 'THE', 'DEASEAS', 'CSV', 'IN', 'WHICH', 'THE', 'DATA', 'FOR', 'THE', 'PEOPLE', 'WITH', 'SOME', 'DIESEASE', 'IS', 'GIVEN', 'IN', 'WHICH', 'THE', 'DEASDES', 'TABLE', 'AND', 'THE', 'BP', 'HIGHT', 'LEVEL', 'IS', 'GIVEN', '2', '5MGLL']

# %%
setwords =set(stopwords.words('english'))
filtered_tokens = list(filter(lambda word : Hello))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~\anaconda3\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - 'C:\\Users\\Lenovo/nltk_data'
# ...

# %%
import cv2
import numpy as np
