# %%
l = [1,2,3,4]

# Empty list
my_list = []

# List with elements
numbers = [1, 2, 3, 4, 5]

# Mixed data types
mixed_list = [1, "Hello", 3.14, True]

# %%
l , numbers
l.append(1)
l2=[6,7,8,9,0]
l.extend(l2)

# %%
l
# Out:
# [1, 2, 3, 4, 1, 1, 6, 7, 8, 9, 0]

# %%
l.insert(1,200)

# %%
l
# Out:
# [1, 200, 2, 3, 4, 1, 1, 6, 7, 8, 9, 0]

# %%
l.remove(200)
l
# Out:
# [1, 2, 3, 4, 1, 1, 6, 7, 8, 9, 0]

# %%
l.pop(2)
# Out:
# 3

# %%
l.index(2)
l.count(1)
l.sort()
# Out:
# 3

# %%
l
# Out:
# [1, 1, 1, 2, 4, 6, 7, 8, 9]

# %%
l.reverse()

# %%
l
# Out:
# [9, 8, 7, 6, 4, 2, 1, 1, 1]

# %%
l3= l.copy()
l3.append(100)
l3
# Out:
# [9, 8, 7, 6, 4, 2, 1, 1, 1, 100]

# %%
l.clear()

# %%
l,l2,l3
# Out:
# ([], [6, 7, 8, 9, 0], [9, 8, 7, 6, 4, 2, 1, 1, 1, 100])

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")
print(fruits)  # ['apple', 'banana', 'cherry', 'orange']

fruits.sort() #makes the list in the so
print(fruits)  # ['apple', 'banana', 'cherry', 'orange']
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry', 'orange']

# %%
sorted(l3) #returns a new list which is the original version of the list 
l3
# Out:
# [9, 8, 7, 6, 4, 2, 1, 1, 1, 100]
