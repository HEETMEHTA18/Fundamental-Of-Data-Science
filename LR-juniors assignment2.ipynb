# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import load_advertising
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[152], line 5
#       3 import matplotlib.pyplot as plt
#       4 import sklearn
# ----> 5 import load_advertising
#
# ModuleNotFoundError: No module named 'load_advertising'

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import datasets
# Out:
#   Cell In[151], line 4
#     from sklearn import datasets import load_advertising
#                                  ^
# SyntaxError: invalid syntax

# %%
data = pd.read_csv("assignment-dataset-2.csv")

# %%
data.head()
# Out:
#            X  Y_Quadratic
# 0 -10.000000    53.993428
# 1  -9.310345    46.064732
# 2  -8.620690    41.453522
# 3  -7.931034    37.496714
# 4  -7.241379    28.750480

# %%
X = data[['X']]
y = data[['Y_Quadratic']]

# %%
y
# Out:
#     Y_Quadratic
# 0     53.993428
# 1     46.064732
# 2     41.453522
# 3     37.496714
# 4     28.750480
# 5     23.994271
# 6     23.340352
# 7     17.911802
# 8     12.108614
# 9     11.278937
# 10     6.888860
# 11     4.981739
# 12     4.970250
# 13    -0.291483
# 14    -0.390383
# 15     1.934878
# 16     1.509415
# 17     5.114820
# 18     4.097150
# 19     4.991088
# 20    13.125114
# 21    12.596010
# 22    16.511989
# 23    17.332430
# 24    23.373779
# 25    29.440632
# 26    32.148667
# 27    40.909541
# 28    45.139983
# 29    52.416613

# %%
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.5, random_state=42
# )
##train test and validation split
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_[0]
# Out:
# array([1.8330686])

# %%
model.intercept_
# Out:
# array([34.08592648])

# %%
y_pred = model.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 599.4746229094584

# %%
r2_score(y_test, y_pred)
# Out:
# -1.1482390200735133

# %%
plt.scatter(X, y, color='blue')
plt.plot(X, model.predict(X), color='red')
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Regression Fit")
plt.show()

# %%
dataset=datasets.load_advertising()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\sklearn\datasets\__init__.py:166, in __getattr__(name)
#     165 try:
# --> 166     return globals()[name]
#     167 except KeyError:
#     168     # This is turned into the appropriate ImportError
#
# KeyError: 'load_advertising'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 dataset=datasets.load_advertising()
#
# File c:\Users\Lenovo\anaconda3\Lib\site-packages\sklearn\datasets\__init__.py:169, in __getattr__(name)
#     166     return globals()[name]
#     167 except KeyError:
#     168     # This is turned into the appropriate ImportError
# --> 169     raise AttributeError
#
# AttributeError:
